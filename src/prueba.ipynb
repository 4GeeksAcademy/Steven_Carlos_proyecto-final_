# %%
# import streamlit as st
# import pandas as pd
# import numpy as np
# import joblib 
# # Nota: Si aún no tienes el modelo, el código simulará la predicción,
# # pero necesitas tener xgboost instalado para que no falle el import.
# from xgboost import XGBClassifier



# # --- CONFIGURACIÓN DE LA PÁGINA ---
# st.set_page_config(page_title="Predicador de Fútbol Pro", layout="wide")

# st.title("⚽ Dashboard de Predicción de Resultados")
# st.markdown("""
# Esta aplicación utiliza un modelo **XGBoost** entrenado con datos históricos (2000-2025) 
# para predecir la probabilidad de un resultado multiclase: Local, Empate o Visitante.
# """)

# # --- SIMULACIÓN DE CARGA DE MODELO Y CODIFICADORES ---
# # En un entorno real, aquí cargarías tu modelo:
# # modelo = joblib.load('modelo_final.pkl')

# def user_input_features():
#     st.sidebar.header("📊 Parámetros del Partido")
    
#     col1, col2 = st.sidebar.columns(2)
    
#     with col1:
#         home_elo = st.slider("Home ELO", 1000, 3000, 1500)
#         odd_home = st.number_input("Cuota Local", 1.0, 20.0, 2.10)
#         form_home = st.slider("Forma Local (5)", 0.0, 1.0, 0.5)
        
#     with col2:
#         away_elo = st.slider("Away ELO", 1000, 3000, 1500)
#         odd_away = st.number_input("Cuota Visitante", 1.0, 20.0, 3.20)
#         form_away = st.slider("Forma Visitante (5)", 0.0, 1.0, 0.5)

#     odd_draw = st.sidebar.number_input("Cuota Empate", 1.0, 10.0, 3.10)
    
#     data = {
#         'HomeElo': home_elo, 'AwayElo': away_elo,
#         'OddHome': odd_home, 'OddDraw': odd_draw, 'OddAway': odd_away,
#         'Form5Home': form_home, 'Form5Away': form_away,
#         'Anio': 2024, 'Mes': 2, 'Dia_Semana': 5,
#         'Hora_Seno': 0.5, 'Hora_Coseno': 0.8 # Valores por defecto o calculados
#     }
#     return pd.DataFrame(data, index=[0])

# # --- INTERFAZ PRINCIPAL ---
# df_input = user_input_features()

# col_main1, col_main2 = st.columns([1, 2])

# with col_main1:
#     st.subheader("Datos de entrada")
#     st.write(df_input.T) # Transpuesto para que se lea mejor verticalmente

# with col_main2:
#     st.subheader("🔮 Predicción del Modelo")
    
#     # --- AQUÍ OCURRE LA MAGIA (SIMULADA) ---
#     # En producción usarías: prediccion = modelo.predict_proba(df_input)
    
#     # Simulamos valores para que la app funcione visualmente ahora mismo:
#     probs = [0.45, 0.25, 0.30] # [Local, Empate, Visitante]
#     clases = ['Victoria Local (H)', 'Empate (D)', 'Victoria Visitante (A)']
    
#     # Mostrar resultados en barras de progreso estilizadas
#     for i in range(len(clases)):
#         st.write(f"**{clases[i]}**")
#         st.progress(probs[i])
#         st.write(f"Probabilidad: {probs[i]*100:.1f}%")

#     st.success(f"Resultado más probable: **{clases[np.argmax(probs)]}**")

# # --- GRÁFICO DE IMPORTANCIA (Opcional) ---
# st.divider()
# st.subheader("📈 ¿Qué está mirando el modelo?")
# st.info("El modelo prioriza el **HomeElo** y la **Cuota Local** para tomar esta decisión.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
